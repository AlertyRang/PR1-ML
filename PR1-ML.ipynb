# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vgsales_4.csv')
df
# Out:
#       Rank                                        Name Platform    Year
# 0      435           Club Penguin: Elite Penguin Force       DS  2008.0  \
# 1    13444                      Secret Files: Tunguska       PC  2006.0
# 2    10126                            ECW Anarchy Rulz       PS  1999.0
# 3     7585  Taiko no Tatsujin: Waku Waku Anime Matsuri      PS2  2003.0
# 4    10242                                    Breakout       PS  1999.0
# ..     ...                                         ...      ...     ...
# 548  11703              Genkai Totsuki Moero Chronicle      PSV  2014.0
# 549  13732                          GoGo's Crazy Bones       DS  2012.0
# 550    701                         Yokai Watch Busters      3DS  2015.0
# 551  12849                             Princess on Ice       DS  2008.0
# 552  14554                      Let's Dance with Mel B      PS3  2011.0
#
#             Genre                   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
df.shape
# Out:
# (553, 11)

# %%
df.head(5)
# Out:
#     Rank                                        Name Platform    Year
# 0    435           Club Penguin: Elite Penguin Force       DS  2008.0  \
# 1  13444                      Secret Files: Tunguska       PC  2006.0
# 2  10126                            ECW Anarchy Rulz       PS  1999.0
# 3   7585  Taiko no Tatsujin: Waku Waku Anime Matsuri      PS2  2003.0
# 4  10242                                    Breakout       PS  1999.0
#
#        Genre                   Publisher  NA_Sales  EU_Sales  JP_Sales
# 0  Adventure  Disney Interactive Studios      1.88      0.98       0.0  \
# 1  Adventure    DreamCatcher Interactive      0.00      0.04       0.0
# 2   Fighting       Acclaim Entertainment      0.06      0.04       0.0
# 3       Misc          Namco Bandai Games      0.00      0.00       0.2
# 4     Puzzle          Hasbro Interactive      0.06      0.04       0.0
#
#    Other_Sales  Global_Sales
# 0         0.30          3.16
# 1         0.01          0.05
# ...

# %%
df.tail(5)
# Out:
#       Rank                            Name Platform    Year         Genre
# 548  11703  Genkai Totsuki Moero Chronicle      PSV  2014.0  Role-Playing  \
# 549  13732              GoGo's Crazy Bones       DS  2012.0        Action
# 550    701             Yokai Watch Busters      3DS  2015.0        Action
# 551  12849                 Princess on Ice       DS  2008.0        Sports
# 552  14554          Let's Dance with Mel B      PS3  2011.0        Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 548           Compile Heart      0.00      0.00      0.08         0.00  \
# 549  GameMill Entertainment      0.00      0.04      0.00         0.00
# 550                 Level 5      0.00      0.00      2.28         0.00
# 551               505 Games      0.04      0.01      0.00         0.00
# 552        Black Bean Games      0.00      0.02      0.00         0.01
#
#      Global_Sales
# 548          0.08
# 549          0.04
# 550          2.28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          553 non-null    int64
#  1   Name          553 non-null    object
#  2   Platform      553 non-null    object
#  3   Year          542 non-null    float64
#  4   Genre         553 non-null    object
#  5   Publisher     552 non-null    object
#  6   NA_Sales      553 non-null    float64
#  7   EU_Sales      553 non-null    float64
#  8   JP_Sales      553 non-null    float64
#  9   Other_Sales   553 non-null    float64
#  10  Global_Sales  553 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 47.7+ KB

# %%
df.describe()
# Out:
#                Rank         Year    NA_Sales    EU_Sales    JP_Sales
# count    553.000000   542.000000  553.000000  553.000000  553.000000  \
# mean    7984.151899  2006.719557    0.257740    0.150416    0.083599
# std     4816.212409     5.624638    0.598763    0.435015    0.374582
# min       13.000000  1981.000000    0.000000    0.000000    0.000000
# 25%     3691.000000  2003.000000    0.000000    0.000000    0.000000
# 50%     7738.000000  2008.000000    0.090000    0.030000    0.000000
# 75%    12119.000000  2011.000000    0.280000    0.120000    0.040000
# max    16584.000000  2016.000000    9.000000    6.180000    7.200000
#
#        Other_Sales  Global_Sales
# count   553.000000    553.000000
# mean      0.049439      0.541284
# std       0.156615      1.338900
# min       0.000000      0.010000
# 25%       0.000000      0.070000
# 50%       0.010000      0.190000
# 75%       0.040000      0.540000
# max       2.460000     23.100000

# %%
df.where(df['Year'] == 2012).dropna()
# Out:
#         Rank                                               Name Platform
# 21    2745.0           The Amazing Spider-Man (Console Version)     X360  \
# 25   12951.0                      Persona 2: Eternal Punishment      PSP
# 47   10688.0                               Tales of Innocence R      PSV
# 66    6436.0              Atelier Ayesha: The Alchemist of Dusk      PS3
# 80   13558.0                    Record of Agarest War: Marriage      PSP
# 88    8683.0                                            WWE '13      Wii
# 118  11731.0    Nicola Kanshuu: Model Oshare * Audition Platina      3DS
# 119  15515.0  Soukoku no Kusabi: Hiiro no Kakera 3 - Ashita ...      PSP
# 161   3950.0                                            F1 2012     X360
# 167  16318.0                                     Gakuen Hetalia       DS
# 186   7952.0                             Pro Yaky? Spirits 2012      PS3
# 239  13157.0                                           Guild 01      3DS
# ...

# %%
print('Кол-во уник наименований', len(df.Name.unique()))
print('Наименования', df.Name.unique())
# Out:
# Кол-во уник наименований 536
# Наименования ['Club Penguin: Elite Penguin Force' 'Secret Files: Tunguska'
#  'ECW Anarchy Rulz' 'Taiko no Tatsujin: Waku Waku Anime Matsuri'
#  'Breakout' 'Famicom Mini: Balloon Fight' "Let's Draw!"
#  'Dora the Explorer: Super Spies' 'Earthworm Jim 3D'
#  'PDC World Championship Darts: Pro Tour' "Cabela's Dangerous Hunts 2011"
#  'Jeremy McGrath Supercross World'
#  'Ringling Bros. and Barnum & Bailey Circus' 'Burstrick: Wake Boarding!!'
#  'Knights Contract' 'VMX Racing' 'Scripps Spelling Bee'
#  'Pokemon Gold/Pokemon Silver' "Tom Clancy's Ghost Recon 2"
#  'Major League Baseball 2K13' 'Injustice: Gods Among Us'
#  'The Amazing Spider-Man (Console Version)'
#  'Final Fantasy II Anniversary Edition'
#  "Sonic Adventure DX: Director's Cut" 'Championship Foosball'
#  'Persona 2: Eternal Punishment' 'Ray Gigant' 'My Baby: First Steps'
#  'Gallop Racer' 'Cubic Ninja' 'Mario Party 3' 'BeatMania Append GottaMix'
# ...

# %%
print('Процент уникальных игр', len(df.Name.unique()) / len(df) * 100 , '%')
# Out:
# Процент уникальных игр 96.9258589511754 %

# %%
print('Процент не уникальных игр', 100 - len(df.Name.unique()) / len(df) * 100 , '%')
# Out:
# Процент не уникальных игр 3.0741410488246004 %

# %%
publishers = df.groupby(['Publisher','Year'])['Name'].value_counts()
print("Игры выпущенные несколько раз одним и тем же издателем", publishers.where(publishers >1).dropna())
# Out:
# Игры выпущенные несколько раз одним и тем же издателем Publisher                     Year    Name
# Activision                    2007.0  Tony Hawk's Proving Ground                                         2.0
#                               2009.0  Call of Duty: Modern Warfare 2                                     2.0
# Codemasters                   2012.0  F1 2012                                                            2.0
# Electronic Arts               2000.0  NASCAR Rumble                                                      2.0
#                               2002.0  Ty the Tasmanian Tiger                                             2.0
#                               2005.0  Burnout Revenge                                                    2.0
#                               2011.0  Need for Speed: The Run                                            2.0
#                               2013.0  FIFA 14                                                            2.0
# ...

# %%
df.loc[df['Publisher'] == 'Activision']
# Out:
#       Rank                                               Name Platform
# 10    5516                      Cabela's Dangerous Hunts 2011      PS3  \
# 21    2745           The Amazing Spider-Man (Console Version)     X360
# 35    6089                          World of Warcraft: Legion       PC
# 54    5803                                           Blade II      PS2
# 73    6646                         Tony Hawk's Proving Ground      Wii
# 109   6828                              Skylanders SWAP Force      3DS
# 113   6939                           Tony Hawk's Downhill Jam      Wii
# 133   2137                      Skylanders: Spyro's Adventure     X360
# 152   7752                     Ice Age: Dawn of the Dinosaurs      PS3
# 156   2349                     Call of Duty: Modern Warfare 2       PC
# 165   6534               Indiana Jones and the Staff of Kings      PSP
# 177   9229                                       Science Papa      Wii
# ...

# %%
print('Кол-во уник жанров:', len(df.Genre.unique()))
print('Жанры:', df.Genre.unique())
print('Кол-во жанров', df.Genre.value_counts())
# Out:
# Кол-во уник жанров: 12
# Жанры: ['Adventure' 'Fighting' 'Misc' 'Puzzle' 'Action' 'Platform' 'Sports'
#  'Racing' 'Simulation' 'Role-Playing' 'Shooter' 'Strategy']
# Кол-во жанров Genre
# Action          106
# Sports           86
# Misc             59
# Role-Playing     53
# Shooter          40
# Adventure        39
# Racing           39
# Platform         34
# Fighting         31
# Simulation       27
# Strategy         21
# Puzzle           18
# Name: count, dtype: int64

# %%
print('Кол-во уникальных платформ:',len(df['Platform'].unique()))
print(df.Platform.value_counts())
# Out:
# Кол-во уникальных платформ: 24
# Platform
# DS      64
# PS2     63
# PSP     52
# PS3     49
# Wii     48
# PS      41
# X360    39
# GBA     31
# XB      30
# PC      27
# GC      18
# 3DS     17
# PSV     13
# XOne    13
# N64     12
# PS4     10
# SNES     8
# GB       4
# 2600     4
# WiiU     3
# SAT      3
# NES      2
# 3DO      1
# NG       1
# Name: count, dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Rank            0.000000
# Name            0.000000
# Platform        0.000000
# Year            1.989150
# Genre           0.000000
# Publisher       0.180832
# NA_Sales        0.000000
# EU_Sales        0.000000
# JP_Sales        0.000000
# Other_Sales     0.000000
# Global_Sales    0.000000
# dtype: float64

# %%
df = df.drop_duplicates(subset=['Name','Platform'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546 entries, 0 to 552
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          546 non-null    int64
#  1   Name          546 non-null    object
#  2   Platform      546 non-null    object
#  3   Year          535 non-null    float64
#  4   Genre         546 non-null    object
#  5   Publisher     545 non-null    object
#  6   NA_Sales      546 non-null    float64
#  7   EU_Sales      546 non-null    float64
#  8   JP_Sales      546 non-null    float64
#  9   Other_Sales   546 non-null    float64
#  10  Global_Sales  546 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 51.2+ KB

# %%
df.drop(columns=['NA_Sales'])
# Out:
#       Rank                                        Name Platform    Year
# 0      435           Club Penguin: Elite Penguin Force       DS  2008.0  \
# 1    13444                      Secret Files: Tunguska       PC  2006.0
# 2    10126                            ECW Anarchy Rulz       PS  1999.0
# 3     7585  Taiko no Tatsujin: Waku Waku Anime Matsuri      PS2  2003.0
# 4    10242                                    Breakout       PS  1999.0
# ..     ...                                         ...      ...     ...
# 548  11703              Genkai Totsuki Moero Chronicle      PSV  2014.0
# 549  13732                          GoGo's Crazy Bones       DS  2012.0
# 550    701                         Yokai Watch Busters      3DS  2015.0
# 551  12849                             Princess on Ice       DS  2008.0
# 552  14554                      Let's Dance with Mel B      PS3  2011.0
#
#             Genre                   Publisher  EU_Sales  JP_Sales
# ...

# %%
df = df.replace({'Name' : 'Club Penguin: Elite Penguin Force'}, 'RoflGame')
df
# Out:
#       Rank                                        Name Platform    Year
# 0      435                                    RoflGame       DS  2008.0  \
# 1    13444                      Secret Files: Tunguska       PC  2006.0
# 2    10126                            ECW Anarchy Rulz       PS  1999.0
# 3     7585  Taiko no Tatsujin: Waku Waku Anime Matsuri      PS2  2003.0
# 4    10242                                    Breakout       PS  1999.0
# ..     ...                                         ...      ...     ...
# 548  11703              Genkai Totsuki Moero Chronicle      PSV  2014.0
# 549  13732                          GoGo's Crazy Bones       DS  2012.0
# 550    701                         Yokai Watch Busters      3DS  2015.0
# 551  12849                             Princess on Ice       DS  2008.0
# 552  14554                      Let's Dance with Mel B      PS3  2011.0
#
#             Genre                   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
from sklearn.impute import SimpleImputer

simp = SimpleImputer(missing_values=np.nan)
simp = simp.fit(df[['Year']])

df['Year'] = simp.transform(df[['Year']])
df.isnull().mean()*100
# Out:
# Rank            0.00000
# Name            0.00000
# Platform        0.00000
# Year            0.00000
# Genre           0.00000
# Publisher       0.18315
# NA_Sales        0.00000
# EU_Sales        0.00000
# JP_Sales        0.00000
# Other_Sales     0.00000
# Global_Sales    0.00000
# dtype: float64

# %%
df.to_csv('dff.csv', index=False)
